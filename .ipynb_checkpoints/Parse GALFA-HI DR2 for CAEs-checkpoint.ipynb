# %%
import numpy as np
import os,sys
from scipy import misc
# %matplotlib inline
from matplotlib import pyplot as plt

# %% [markdown]
# OK, we need to read in some data. I wanted to get some data that look human-understandable, and crushed out a lot of the amplitude variation we see in the ISM. I am just going to use my "promotional" ISM images from GALFA-HI DR2 to start with.

# %%
#Let's test reading a PNG
whereami ='/Users/jegpeek/'
path = 'Dropbox/Documents/batch/GALFA/DR2/testmovie/allsky/'
file = 'allsky988.png'

# %%
#read in all the data
# I am going to break things down into 32x32s, but do an offset so we don't get exact match ups of the same features...
nacross = np.floor(10800/32.0)
f1 = 970
f2 = 1077
ntall = np.floor(1180/32.0)
nfiles = (1077-970+1)
filenums = np.linspace(f1,f2, nfiles)
filenames = np.array(nfiles, dtype=str)
for i in range(nfiles):
    filename[i] = 'allsky%d.png'%(filenums[i],)

#image = misc.imread(whereami + path + file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-f508180dbcbb> in <module>()
#       9 filenames = np.array(nfiles, dtype=str)
#      10 for i in range(nfiles):
# ---> 11     filename[i] = whereami + path + 'allsky%d.png'%(filenums[i],)
#      12
#      13 #image = misc.imread(whereami + path + file)
#
# TypeError: 'str' object does not support item assignment

# %%
filenums[0]
# Out:
# 970.0

# %%
image.shape
# Out:
# (1180, 10800, 3)

# %%
plt.imshow(image)

# %%
misc.imsave('test.png', image[600:640, 2000:2040,  :])

# %%
print(10800/32)
# Out:
# 337.5

# %%
for i in range(10):
    filename = 'data_%d.dat'%(i,)
    print(filename)
# Out:
# data_0.dat
# data_1.dat
# data_2.dat
# data_3.dat
# data_4.dat
# data_5.dat
# data_6.dat
# data_7.dat
# data_8.dat
# data_9.dat

# %%
filenames = whereami + path + 'allsky%d.png'%(i for [i in filenums])
# Out:
#   File "<ipython-input-42-d486ee731100>", line 1
#     filenames = whereami + path + 'allsky%d.png'%(i for [i in filenums])
#                                                                        ^
# SyntaxError: invalid syntax

# %%
filenames
# Out:
# '/Users/jegpeek/Dropbox/Documents/batch/GALFA/DR2/testmovie/allsky/allsky0.png'

# %%
result = whereami + path + 'allsky'.join("&markers=%s" % ','.join(map(str, x)) for x in markers)
